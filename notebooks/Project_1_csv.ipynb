# %% [markdown]
# # City of Chicago Yearly Budget Analysis - Data Cleanup & Exploration
#
# ## Sources
#
# Data is taken from the City of Chicago Data Portal website:
#
# https://data.cityofchicago.org/
#
# Specifically the 2011 through 2017 "Budget Ordinance - Positions and Salaries" APIs found in the Administration & Finance category
#
# CAFR - Comprehensive Annual Financial Reports for the City of Chicago

# %% [markdown]
# ## Read in the Data
#
# - City of Chicago Budgets (by Department) from 2011 to 2017
# - City of Chicago Financial Information from 2011 to 2016

# %%
#Dependencies
import pandas as pd

# %%
# Store filepath in a variable
budget_data = "budget_by_year.csv"
financial_data = "City.Chicago.Financials.csv"

# %%
# Read our Data file with the pandas library
budget_by_year_df = pd.read_csv(budget_data, encoding="ISO-8859-1")
yearly_financials = pd.read_csv(financial_data, encoding="ISO-8859-1")

# %% [markdown]
# ## Clean and Format the City Budget Data

# %%
# Cleaning the department description to eliminate descrepancies in department descriptions between years
budget_by_year_df['department_description'].replace('BUS AFFAIRS AND CONSUMER PROT', \
                                                    'BUSINESS AFFAIRS AND CONSUMER PROTECTION', inplace=True)
budget_by_year_df['department_description'].replace('DOIT', \
                                                    'DEPARTMENT OF INNOVATION & TECHNOLOGY', inplace=True)
budget_by_year_df['department_description'].replace('FINANCE', \
                                                    'DEPARTMENT OF FINANCE', inplace=True)
budget_by_year_df['department_description'].replace('IPRA', \
                                                    'INDEPENDENT POLICE REVIEW AUTHORITY', inplace=True)
budget_by_year_df['department_description'].replace(['FLEET AND FACILITY MANAGEMENT', 'FLEET AND FACILITY MGMT'], \
                                                    'DEPARTMENT OF FLEET MANAGEMENT', inplace=True)
budget_by_year_df['department_description'].replace('OEMC', \
                                                    'OFFICE OF EMERGENCY MANAGEMENT & COMMUNICATIONS', inplace=True)
budget_by_year_df['department_description'].replace(['IG', 'OIG'], \
                                                    'INSPECTOR GENERAL', inplace=True)
budget_by_year_df['department_description'].replace('PLANNING AND DEVELOPMENT', \
                                                    'HOUSING AND ECONOMIC DEVELOPMT', inplace=True)
budget_by_year_df['department_description'].replace('ADMINISTRATIVE HEARINGS', \
                                                    'DEPT OF ADMINISTRATIVE HEARING', inplace=True)
budget_by_year_df['department_description'].replace('ANIMAL CARE AND CONTROL', \
                                                    'COMM ANIMAL CARE AND CONTROL', inplace=True)
budget_by_year_df['department_description'].replace('BACP', \
                                                    'BUSINESS AFFAIRS AND CONSUMER PROTECTION', inplace=True)
budget_by_year_df['department_description'].replace('CDOT', \
                                                    'CHICAGO DEPT OF TRANSPORTATION', inplace=True)
budget_by_year_df['department_description'].replace('DCASE', \
                                                    'CULTURAL AFFAIRS SPECIAL EVENT', inplace=True)
budget_by_year_df['department_description'].replace('DEPARTMENT OF BUILDINGS', \
                                                    'DEPT OF BUILDINGS', inplace=True)
budget_by_year_df['department_description'].replace('PROCUREMENT SERVICES', \
                                                    'DEPARTMENT OF PROCUREMENT SERV', inplace=True)
budget_by_year_df['department_description'].replace('STREETS AND SANITATION', \
                                                    'DEPT STREETS AND SANITATION', inplace=True)
budget_by_year_df['department_description'].replace('OBM', \
                                                    'OFFICE OF BUDGET & MANAGEMENT', inplace=True)
budget_by_year_df['department_description'].replace('WATER MANAGEMENT', \
                                                    'DEPT OF WATER MANAGEMENT', inplace=True)
budget_by_year_df['department_description'].replace('MOPD', \
                                                    'MAYORS OFFICE-DISABILITIES', inplace=True)
budget_by_year_df['department_description'].replace('CHICAGO FIRE DEPARTMENT', \
                                                    'FIRE DEPARTMENT', inplace=True)
budget_by_year_df['department_description'].replace('CHICAGO POLICE DEPARTMENT', \
                                                    'DEPARTMENT OF POLICE', inplace=True)

# %% [markdown]
# ### Find the number of employees paid annualy
#
# - per year
# - per department

# %%
# Pull annual salaried employees into a dataframe
annual_df = budget_by_year_df.loc[budget_by_year_df["budgeted_unit"] == "Annual", :]
annual_df.head()
# Out:
#    year fund_type fund_code     fund_description  department_number  \
# 0  2011     Local       300         VEHICLE FUND               25.0
# 1  2011     Local       610  MIDWAY AIRPORT FUND               27.0
# 2  2011     Local       610  MIDWAY AIRPORT FUND               27.0
# 3  2011     Local       100       CORPORATE FUND               28.0
# 4  2011     Local       100       CORPORATE FUND               28.0
#
#   department_description  organization_code  division_code  \
# 0             CITY CLERK               1005         2005.0
# 1  DEPARTMENT OF FINANCE               1005         2005.0
# 2  DEPARTMENT OF FINANCE               1005         2005.0
# 3         CITY TREASURER               1005         2005.0
# 4         CITY TREASURER               1005         2005.0
#
#   division_description  section_code            section_description  \
# 0           City Clerk        3030.0  Vehicle License Data Services
# 1     City Comptroller        3030.0                       Auditing
# 2     City Comptroller        3030.0                       Auditing
# 3       City Treasurer        3015.0            Financial Reporting
# 4       City Treasurer        3015.0            Financial Reporting
#
#   title_code            title_description budgeted_unit  total_budgeted_unit  \
# 0         15  Schedule Salary Adjustments        Annual                    0
# 1         15  Schedule Salary Adjustments        Annual                    0
# 2        102                Accountant II        Annual                    1
# 3        104                Accountant IV        Annual                    1
# 4        104                Accountant IV        Annual                    1
#
#    budgeted_pay_rate  total_budgeted_amount
# 0             2485.0                 2485.0
# 1             2389.0                 2389.0
# 2            73932.0                73932.0
# 3            76536.0                76536.0
# 4            88140.0                88140.0

# %%
# List of years in the data set
years = [2011, 2012, 2013, 2014, 2015, 2016, 2017]

# Empty dataframe to append employee counts to
dep_count = pd.DataFrame()

# loop through the annual salaried employee datafrome by year
for year in years:
    
    # Create a dataframe for a specific year
    aby_df = annual_df.loc[annual_df["year"] == year, :]
    
    # Create a groupby object based on department
    aby_gp = aby_df.groupby("department_description")
    
    # Sum the number of annual salaried employees per department   
    aby_dep_count = aby_gp["total_budgeted_unit"].sum()
    
    # append to the employee count datafrome
    dep_count.loc[:, f"{year} Dept Annual Employees"] = aby_dep_count

# %% [markdown]
# ### Find the number of employees paid monthly
#
# - per year
# - per department

# %%
# Pull monthly salaried employees into a dataframe
monthly_df = budget_by_year_df.loc[budget_by_year_df["budgeted_unit"] == "Monthly", :]
monthly_df.head()
# Out:
#       year fund_type fund_code fund_description  department_number  \
# 427   2011     Local       300     VEHICLE FUND               25.0
# 693   2011     Local       100   CORPORATE FUND               29.0
# 785   2011     Local       100   CORPORATE FUND               29.0
# 1579  2011     Local       100   CORPORATE FUND               38.0
# 1587  2011     Local       100   CORPORATE FUND               38.0
#
#      department_description  organization_code  division_code  \
# 427              CITY CLERK               1005         2005.0
# 693   DEPARTMENT OF REVENUE               1005         2003.0
# 785   DEPARTMENT OF REVENUE               1005         2003.0
# 1579       GENERAL SERVICES               1005         2125.0
# 1587       GENERAL SERVICES               1005         2125.0
#
#                           division_description  section_code  \
# 427                                 City Clerk        3025.0
# 693                      Department of Revenue        3154.0
# 785                      Department of Revenue        3157.0
# 1579  Bureau Trades and Engineering Management        3182.0
# 1587  Bureau Trades and Engineering Management        3183.0
#
#                section_description title_code  \
# 427   Issuance of Vehicle Licenses        429
# 693             Payment Processing        235
# 785              Street Operations       7482
# 1579          Building Engineering       7747
# 1587                Trade Services       4526
#
#                       title_description budgeted_unit  total_budgeted_unit  \
# 427                            Clerk II       Monthly                   24
# 693     Payment Services Representative       Monthly                   12
# 785            Parking Enforcement Aide       Monthly                 1272
# 1579           Chief Operating Engineer       Monthly                    5
# 1587  General Foreman of General Trades       Monthly                    2
#
#       budgeted_pay_rate  total_budgeted_amount
# 427              2298.0                55152.0
# 693              3036.0                36432.0
# 785              2944.0              3744768.0
# 1579             8698.0               521872.0
# 1587             8713.0               209123.0

# %%
# List of departments
depts = dep_count.index

# loop through monthly salaried employee datafrome by year
for year in years:
    
    # Create a dataframe for a specific year
    mby_df = monthly_df.loc[monthly_df["year"] == year, :]
    
    # empty list to hold yearly monthly employee counts for a given year
    mby_list = []
    
    # loop through city departments
    for department in depts:
        
        # Create a dataframe for a specific department
        mby_dept_df = mby_df.loc[mby_df["department_description"] == department, :]
        
        # empty list to hold department employee counts
        mbd_list = []
        
        # loop through the rows for a given department
        for x in range(0, len(mby_dept_df)):
            
            # some of the data given is in 12 months increments per employee which is evident by the following:
            # total_budgeted_unit = 24; budgeted_pay_rate = 2298; total_budgeted_amount = 55152
            # this if statement appends that data
            if mby_dept_df.iloc[x, 14] * (mby_dept_df.iloc[x, 15] + 5) > mby_dept_df.iloc[x, 16]:
                
                mbd_list.append(mby_dept_df.iloc[x, 14]/12)
            
            # some of the data is given as number of employees which is evident by the the following:
            # total_budgeted_unit = 2; budgeted_pay_rate = 8713; total_budgeted_amount = 209123
            # the number of months per year (12) must be manually applied: 2 * 12 * 8713 = 209123
            # this else statement appends that data
            else:
                
                mbd_list.append(mby_dept_df.iloc[x, 14])
                
        # sum the employee numbers appended in the conditional statement above
        mby_list.append(sum(mbd_list))
    
    # Append the yearly monthly salaried employee data to the overall dataframe
    dep_count.loc[:, f"{year} Dept Monthly Employees"] = mby_list

# %% [markdown]
# ### Find the number of employees paid hourly
#
# - per year
# - per department

# %%
# Pull hourly salaried employees into a dataframe
hourly_df = budget_by_year_df.loc[budget_by_year_df["budgeted_unit"] == "Hourly", :]
hourly_df.head()
# Out:
#      year fund_type fund_code fund_description  department_number  \
# 189  2011     Local       100   CORPORATE FUND                5.0
# 266  2011     Local       100   CORPORATE FUND                6.0
# 795  2011     Local       100   CORPORATE FUND               29.0
# 796  2011     Local       100   CORPORATE FUND               29.0
# 797  2011     Local       100   CORPORATE FUND               29.0
#
#                     department_description  organization_code  division_code  \
# 189          OFFICE OF BUDGET & MANAGEMENT               1005         2005.0
# 266  DEPARTMENT OF INNOVATION & TECHNOLOGY               1005         2005.0
# 795                  DEPARTMENT OF REVENUE               1005         2003.0
# 796                  DEPARTMENT OF REVENUE               1005         2003.0
# 797                  DEPARTMENT OF REVENUE               1005         2003.0
#
#                         division_description  section_code  \
# 189          Office of Budget and Management        3035.0
# 266  Department of Innovation and Technology        3140.0
# 795                    Department of Revenue        3157.0
# 796                    Department of Revenue        3157.0
# 797                    Department of Revenue        3157.0
#
#       section_description title_code             title_description  \
# 189        Return to Work       6344               Watchman - TRTW
# 266  Technical Operations       5035           Electrical Mechanic
# 795     Street Operations       7112              Booter - Parking
# 796     Street Operations       7112              Booter - Parking
# 797     Street Operations       7113  Supervising Booter - Parking
#
#     budgeted_unit  total_budgeted_unit  budgeted_pay_rate  \
# 189        Hourly                    0               19.0
# 266        Hourly                    0               40.0
# 795        Hourly                20800               30.0
# 796        Hourly                   30               30.0
# 797        Hourly                    5               32.0
#
#      total_budgeted_amount
# 189                    0.0
# 266                    0.0
# 795               634400.0
# 796              1903200.0
# 797               328328.0

# %%
# loop through hourly salaried employee datafrome by year
for year in years:
    
    # Create a dataframe for a specific year
    hby_df = hourly_df.loc[hourly_df["year"] == year, :]
    
    # empty list to hold yearly hourly employee counts for a given year
    hby_list = []
    
    # loop through city departments
    for department in depts:
        
        # Create a dataframe for a specific department
        hby_dept_df = hby_df.loc[hby_df["department_description"] == department, :]
        
        # empty list to hold department employee counts
        hbd_list = [] 
        
        # loop through the rows for a given department
        for x in range(0, len(hby_dept_df)):
            
            # confirm that the total budget ammount does not equal zero
            if hby_dept_df.iloc[x, 16] != 0:
                
                # some of the data given is in total number of hours per year
                # when this occurs, this statement estimates the number of employees by dividing by 2100 hrs/year and rounding up
                # if total_budgeted_unit * (budgeted_pay_rate + 5 (buffer for rounding)) > total_budgeted_amount
                # note that 2100 hrs/year is assumed to be an approximation of what the departments use
                # based on a calculated sample of the data
                if hby_dept_df.iloc[x, 14] * (hby_dept_df.iloc[x, 15] + 5) > hby_dept_df.iloc[x, 16]:
                    
                    hbd_list.append(int(round(hby_dept_df.iloc[x, 14]/2100)))
                
                # some of the data is given as number of employees
                # this statement appends those values
                else:
                    
                    hbd_list.append(hby_dept_df.iloc[x, 14])
                    
        # sum the employee numbers appended in the conditional statement above
        hby_list.append(sum(hbd_list))
    
    # Append the yearly monthly salaried employee data to the overall dataframe
    dep_count.loc[:, f"{year} Dept Hourly Employees"] = hby_list

# %% [markdown]
# ## Summarize Employee Data

# %%
# remove null values ("NaN")
for year in years:
    dep_count[f"{year} Dept Annual Employees"].fillna(0, inplace=True)
    
# sum total employees per year and append to dataframe
for year in years:
    dep_count.loc[:, f"{year} Dept Total Employees"] = dep_count[f"{year} Dept Annual Employees"] + \
                                                      dep_count[f"{year} Dept Monthly Employees"] + \
                                                     dep_count[f"{year} Dept Hourly Employees"]

# write the dataframe to a csv
dep_count.to_csv("dep_count.csv", index=True)

# Print the employee count dataframe
dep_count.head()
# Out:
#                                           2011 Dept Annual Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                   124
# BOARD OF ETHICS                                                    7
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                         196
# CHICAGO DEPT OF TRANSPORTATION                                   373
# CHICAGO PUBLIC LIBRARY                                           931
#
#                                           2012 Dept Annual Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                 124.0
# BOARD OF ETHICS                                                  8.0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                       180.0
# CHICAGO DEPT OF TRANSPORTATION                                 348.0
# CHICAGO PUBLIC LIBRARY                                         786.0
#
#                                           2013 Dept Annual Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                 119.0
# BOARD OF ETHICS                                                  9.0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                       187.0
# CHICAGO DEPT OF TRANSPORTATION                                 360.0
# CHICAGO PUBLIC LIBRARY                                         771.0
#
#                                           2014 Dept Annual Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                 118.0
# BOARD OF ETHICS                                                  9.0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                       186.0
# CHICAGO DEPT OF TRANSPORTATION                                 361.0
# CHICAGO PUBLIC LIBRARY                                         775.0
#
#                                           2015 Dept Annual Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                 118.0
# BOARD OF ETHICS                                                  9.0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                       186.0
# CHICAGO DEPT OF TRANSPORTATION                                 359.0
# CHICAGO PUBLIC LIBRARY                                         779.0
#
#                                           2016 Dept Annual Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                 118.0
# BOARD OF ETHICS                                                  9.0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                       188.0
# CHICAGO DEPT OF TRANSPORTATION                                 371.0
# CHICAGO PUBLIC LIBRARY                                         794.0
#
#                                           2017 Dept Annual Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                 118.0
# BOARD OF ETHICS                                                  8.0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                       189.0
# CHICAGO DEPT OF TRANSPORTATION                                 376.0
# CHICAGO PUBLIC LIBRARY                                         786.0
#
#                                           2011 Dept Monthly Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                    0.0
# BOARD OF ETHICS                                                   0.0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                          0.0
# CHICAGO DEPT OF TRANSPORTATION                                   85.0
# CHICAGO PUBLIC LIBRARY                                            0.0
#
#                                           2012 Dept Monthly Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                    0.0
# BOARD OF ETHICS                                                   0.0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                          0.0
# CHICAGO DEPT OF TRANSPORTATION                                   78.0
# CHICAGO PUBLIC LIBRARY                                            0.0
#
#                                           2013 Dept Monthly Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                    0.0
# BOARD OF ETHICS                                                   0.0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                          0.0
# CHICAGO DEPT OF TRANSPORTATION                                   78.0
# CHICAGO PUBLIC LIBRARY                                            0.0
#
#                                                     ...              \
# department_description                              ...
# BOARD OF ELECTION COMMISSIONER                      ...
# BOARD OF ETHICS                                     ...
# BUSINESS AFFAIRS AND CONSUMER PROTECTION            ...
# CHICAGO DEPT OF TRANSPORTATION                      ...
# CHICAGO PUBLIC LIBRARY                              ...
#
#                                           2015 Dept Hourly Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                     0
# BOARD OF ETHICS                                                    0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                           5
# CHICAGO DEPT OF TRANSPORTATION                                   844
# CHICAGO PUBLIC LIBRARY                                           160
#
#                                           2016 Dept Hourly Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                     0
# BOARD OF ETHICS                                                    0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                           5
# CHICAGO DEPT OF TRANSPORTATION                                   857
# CHICAGO PUBLIC LIBRARY                                           157
#
#                                           2017 Dept Hourly Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                     0
# BOARD OF ETHICS                                                    0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                           5
# CHICAGO DEPT OF TRANSPORTATION                                   890
# CHICAGO PUBLIC LIBRARY                                           158
#
#                                           2011 Dept Total Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                124.0
# BOARD OF ETHICS                                                 7.0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                      203.0
# CHICAGO DEPT OF TRANSPORTATION                                979.0
# CHICAGO PUBLIC LIBRARY                                       1126.0
#
#                                           2012 Dept Total Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                124.0
# BOARD OF ETHICS                                                 8.0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                      187.0
# CHICAGO DEPT OF TRANSPORTATION                                930.0
# CHICAGO PUBLIC LIBRARY                                        831.0
#
#                                           2013 Dept Total Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                119.0
# BOARD OF ETHICS                                                 9.0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                      194.0
# CHICAGO DEPT OF TRANSPORTATION                                932.0
# CHICAGO PUBLIC LIBRARY                                        903.0
#
#                                           2014 Dept Total Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                118.0
# BOARD OF ETHICS                                                 9.0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                      191.0
# CHICAGO DEPT OF TRANSPORTATION                               1170.0
# CHICAGO PUBLIC LIBRARY                                        934.0
#
#                                           2015 Dept Total Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                118.0
# BOARD OF ETHICS                                                 9.0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                      191.0
# CHICAGO DEPT OF TRANSPORTATION                               1296.0
# CHICAGO PUBLIC LIBRARY                                        939.0
#
#                                           2016 Dept Total Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                118.0
# BOARD OF ETHICS                                                 9.0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                      193.0
# CHICAGO DEPT OF TRANSPORTATION                               1320.0
# CHICAGO PUBLIC LIBRARY                                        951.0
#
#                                           2017 Dept Total Employees
# department_description
# BOARD OF ELECTION COMMISSIONER                                118.0
# BOARD OF ETHICS                                                 8.0
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                      194.0
# CHICAGO DEPT OF TRANSPORTATION                               1361.0
# CHICAGO PUBLIC LIBRARY                                        944.0
#
# [5 rows x 28 columns]

# %%
# Summarize total employee counts in a dataframe
total_dep_emp = dep_count[["2011 Dept Total Employees", "2012 Dept Total Employees", "2013 Dept Total Employees", \
                          "2014 Dept Total Employees", "2015 Dept Total Employees", "2016 Dept Total Employees", \
                          "2017 Dept Total Employees"]]

# write the dataframe to a csv
total_dep_emp.to_csv("total_dep_emp.csv", index=True)

# print the dataframe
total_dep_emp
# Out:
#                                                  2011 Dept Total Employees  \
# department_description
# BOARD OF ELECTION COMMISSIONER                                  124.000000
# BOARD OF ETHICS                                                   7.000000
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                        203.000000
# CHICAGO DEPT OF TRANSPORTATION                                  979.000000
# CHICAGO PUBLIC LIBRARY                                         1126.000000
# CITY CLERK                                                      108.000000
# CITY COUNCIL                                                    234.000000
# CITY TREASURER                                                   22.000000
# COMM ANIMAL CARE AND CONTROL                                     83.000000
# COMMISSION ON HUMAN RELATIONS                                    33.000000
# CULTURAL AFFAIRS SPECIAL EVENT                                   79.000000
# DEPARTMENT OF AVIATION                                         1451.000000
# DEPARTMENT OF ENVIRONMENT                                        82.000000
# DEPARTMENT OF FINANCE                                           200.000000
# DEPARTMENT OF FLEET MANAGEMENT                                  673.000000
# DEPARTMENT OF HUMAN RESOURCES                                    79.000000
# DEPARTMENT OF INNOVATION & TECHNOLOGY                            96.000000

# OFFICE OF EMERGENCY MANAGEMENT & COMMUNICATIONS                     2135.0
# OFFICE OF THE MAYOR                                                   80.0
# POLICE BOARD                                                           2.0

# %% [markdown]
# ## Summarize Budget Data
#
# - per year
# - per department
# - department budget changes between 2011 and 2017

# %%
#empty dataframe to append department budget data to
dep_budgets = pd.DataFrame()

# Loop to add yearly department budgets to the empty dataframe
for year in years:
    
    # Create a dataframe for a specific year
    year_df = budget_by_year_df.loc[budget_by_year_df["year"] == year, :]
    
    # Create a groupby object based on department
    year_gp = year_df.groupby("department_description")
    
    # Sum the budgets per department
    year_dep_budget = year_gp["total_budgeted_amount"].sum()
    
    # append to the budget datafrome
    dep_budgets.loc[:, f"{year} Dept Budgets"] = year_dep_budget

# %%
# make sure all data is an integer and remove null values ("NaN")
for year in years:
    dep_budgets[f"{year} Dept Budgets"].fillna(0, inplace=True)
    dep_budgets[f"{year} Dept Budgets"] = dep_budgets[f"{year} Dept Budgets"].astype(int)

# %%
# write the dataframe to a csv
dep_budgets.to_csv("dep_budgets.csv", index=True)

# print the yearly department budgets
dep_budgets
# Out:
#                                                  2011 Dept Budgets  \
# department_description
# BOARD OF ELECTION COMMISSIONER                             7164438
# BOARD OF ETHICS                                             564692
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                  14289454
# CHICAGO DEPT OF TRANSPORTATION                            77050619
# CHICAGO PUBLIC LIBRARY                                    61214529
# CITY CLERK                                                 6495095
# CITY COUNCIL                                               7779701
# CITY TREASURER                                             1797986
# COMM ANIMAL CARE AND CONTROL                               4253807
# COMMISSION ON HUMAN RELATIONS                              2693324
# CULTURAL AFFAIRS SPECIAL EVENT                             6377498
# DEPARTMENT OF AVIATION                                    98632794
# DEPARTMENT OF ENVIRONMENT                                  6252016
# DEPARTMENT OF FINANCE                                     15480967
# DEPARTMENT OF FLEET MANAGEMENT                            51980691
# DEPARTMENT OF HUMAN RESOURCES                              5639178
# DEPARTMENT OF INNOVATION & TECHNOLOGY                      8899572
# DEPARTMENT OF LAW                                         33819276
# DEPARTMENT OF POLICE                                    1160612152
# DEPARTMENT OF PROCUREMENT SERV                             5944492
# DEPARTMENT OF PUBLIC HEALTH                               71216838
# DEPARTMENT OF REVENUE                                     27225547
# DEPT OF ADMINISTRATIVE HEARING                             2995132
# DEPT OF BUILDINGS                                         27793781
# DEPT OF WATER MANAGEMENT                                 173719856
# DEPT STREETS AND SANITATION                              171978017
# FAMILY AND SUPPORT SERVICES                               43587190
# FIRE DEPARTMENT                                          415494038
# GENERAL SERVICES                                          32296581
# HOUSING AND ECONOMIC DEVELOPMT                            19515395
# INDEPENDENT POLICE REVIEW AUTHORITY                        7561508
# INSPECTOR GENERAL                                          5553703
# LICENSE APPEAL COMMISSION                                    63276
# MAYORS OFFICE-DISABILITIES                                 2514605
# OFFICE OF BUDGET & MANAGEMENT                              3885581
# OFFICE OF COMPLIANCE                                       2676780
# OFFICE OF EMERGENCY MANAGEMENT & COMMUNICATION

# OFFICE OF EMERGENCY MANAGEMENT & COMMUNICATIONS           81346205
# OFFICE OF THE MAYOR                                        7509920
# POLICE BOARD                                                162577
#
#                                                  2017 Dept Budgets
# department_description
# BOARD OF ELECTION COMMISSIONER                             6691812
# BOARD OF ETHICS                                             756420
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                  15133494
# CHICAGO DEPT OF TRANSPORTATION                           117872199
# CHICAGO PUBLIC LIBRARY                                    62347380
# CITY CLERK                                                 6638313
# CITY COUNCIL                                               8397702
# CITY TREASURER                                             2705379
# COMM ANIMAL CARE AND CONTROL                               4707068
# COMMISSION ON HUMAN RELATIONS                              2137901
# CULTURAL AFFAIRS SPECIAL EVENT                             6678326
# DEPARTMENT OF AVIATION                                   132831842
# DEPARTMENT OF ENVIRONMENT                                        0
# DEPARTMENT OF FINANCE                                     46117011
# DEPARTMENT OF FLEET MANAGEMENT                            94179766
# DEPARTMENT OF HUMAN RESOURCES                              6445182
# DEPARTMENT OF INNOVATION & TECHNOLOGY                     12244598
# DEPARTMENT OF LAW                                         35571731
# DEPARTMENT OF POLICE                                    1219409661
# DEPARTMENT OF PROCUREMENT SERV                             8164835
# DEPARTMENT OF PUBLIC HEALTH                               64476642
# DEPARTMENT OF REVENUE                                            0
# DEPT OF ADMINISTRATIVE HEARING                             3226372
# DEPT OF BUILDINGS                                         31023166
# DEPT OF WATER MANAGEMENT                                 197359104
# DEPT STREETS AND SANITATION                              167016513
# FAMILY AND SUPPORT SERVICES                               39597556
# FIRE DEPARTMENT                                          507495453
# GENERAL SERVICES                                                 0
# HOUSING AND ECONOMIC DEVELOPMT                            22361417
# INDEPENDENT POLICE REVIEW AUTHORITY                        5712646
# INSPECTOR GENERAL                                          7707759
# LICENSE APPEAL COMMISSION                                    76932
# MAYORS OFFICE-DISABILITIES                                 2889139
# OFFICE OF BUDGET & MANAGEMENT                              5119568
# OFFICE OF COMPLIANCE                                             0
# OFFICE OF EMERGENCY MANAGEMENT & COMMUNICATIONS           96261836
# OFFICE OF THE MAYOR                                        7672804
# POLICE BOARD                                                172272

# %%
# empty list to append budget changes
budget_changes = []

# list of departments for the dataframe
departments = dep_budgets.index

# Calculate department budget changes between 2011 and 2017
for x in range(0, len(dep_budgets)):
    diff = dep_budgets.iloc[x, 6] - dep_budgets.iloc[x, 0]
    budget_changes.append(diff)
    
# create a dataframe for the budget changes 
diff_budgets = pd.DataFrame({"Departments": departments,
                            "Budget Changes": budget_changes})

# %%
# save a sorted version of the dataframe
diff_budgets_sorted = diff_budgets[["Departments", "Budget Changes"]]
diff_budgets_sorted = diff_budgets_sorted.sort_values('Budget Changes', ascending=False)

# reset the index and print the dataframe
diff_budgets_sorted = diff_budgets_sorted.set_index("Departments")

# write the dataframe to a csv
diff_budgets_sorted.to_csv("diff_budgets_sorted.csv", index=True)

diff_budgets_sorted
# Out:
#                                                  Budget Changes
# Departments
# FIRE DEPARTMENT                                        92001415
# DEPARTMENT OF POLICE                                   58797509
# DEPARTMENT OF FLEET MANAGEMENT                         42199075
# CHICAGO DEPT OF TRANSPORTATION                         40821580
# DEPARTMENT OF AVIATION                                 34199048
# DEPARTMENT OF FINANCE                                  30636044
# DEPT OF WATER MANAGEMENT                               23639248
# OFFICE OF EMERGENCY MANAGEMENT & COMMUNICATIONS        23501661
# DEPARTMENT OF INNOVATION & TECHNOLOGY                   3345026
# DEPT OF BUILDINGS                                       3229385
# HOUSING AND ECONOMIC DEVELOPMT                          2846022
# DEPARTMENT OF PROCUREMENT SERV                          2220343
# INSPECTOR GENERAL                                       2154056
# DEPARTMENT OF LAW                                       1752455
# OFFICE OF BUDGET & MANAGEMENT                           1233987
# CHICAGO PUBLIC LIBRARY                                  1132851
# OFFICE OF THE MAYOR                                     1111990
# CITY TREASURER                                           907393
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                 844040
# DEPARTMENT OF HUMAN RESOURCES                            806004
# CITY COUNCIL                                             618001
# COMM ANIMAL CARE AND CONTROL                             453261
# MAYORS OFFICE-DISABILITIES                               374534
# CULTURAL AFFAIRS SPECIAL EVENT                           300828
# DEPT OF ADMINISTRATIVE HEARING                           231240
# BOARD OF ETHICS                                          191728
# CITY CLERK                                               143218
# POLICE BOARD                                              16896
# LICENSE APPEAL COMMISSION                                 13656
# BOARD OF ELECTION COMMISSIONER                          -472626
# COMMISSION ON HUMAN RELATIONS                           -555423
# INDEPENDENT POLICE REVIEW AUTHORITY                    -1848862
# OFFICE OF COMPLIANCE                                   -2676780
# FAMILY AND SUPPORT SERVICES                            -3989634
# DEPT STREETS AND SANITATION                            -4961504
# DEPARTMENT OF ENVIRONMENT                              -6252016
# DEPARTMENT OF PUBLIC HEALTH                            -6740196
# DEPARTMENT OF REVENUE                                 -27225547
# GENERAL SERVICES                                      -32296581

# %% [markdown]
# ## Summarize Average Salary Data
#
# - per year
# - per department
# - department salary changes between 2011 and 2017

# %%
#empty dataframe to append department salary data to
dep_salaries = pd.DataFrame()

# Loop to add yearly department average salaries to the empty dataframe
for year in years:
    
    dep_salaries.loc[:, f"{year} Dept Avg Salary"] = round(dep_budgets[f"{year} Dept Budgets"]/total_dep_emp[f"{year} Dept Total Employees"],2)

# %%
# make sure all data is an integer and remove null values ("NaN")
for year in years:
    dep_salaries[f"{year} Dept Avg Salary"].fillna(0, inplace=True)

# write the dataframe to a csv
dep_salaries.to_csv("dep_salaries.csv", index=True)
    
# print the department average salaries dataframe
dep_salaries
# Out:
#                                                  2011 Dept Avg Salary  \
# department_description
# BOARD OF ELECTION COMMISSIONER                               57777.73
# BOARD OF ETHICS                                              80670.29
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                     70391.40
# CHICAGO DEPT OF TRANSPORTATION                               78703.39
# CHICAGO PUBLIC LIBRARY                                       54364.59
# CITY CLERK                                                   60139.77
# CITY COUNCIL                                                 33246.59
# CITY TREASURER                                               81726.64
# COMM ANIMAL CARE AND CONTROL                                 51250.69
# COMMISSION ON HUMAN RELATIONS                                81615.88
# CULTURAL AFFAIRS SPECIAL EVENT                               80727.82
# DEPARTMENT OF LAW                                            80479.03
# DEPARTMENT OF POLICE                                         85428.73
# DEPARTMENT OF PROCUREMENT SERV                               80047.40
# DEPARTMENT OF PUBLIC HEALTH                                 106397.10
# DEPARTMENT OF REVENUE                                            0.00
# DEPT OF ADMINISTRATIVE HEARING                               76818.38
# DEPT OF BUILDINGS                                           105520.97
# DEPT OF WATER MANAGEMENT                                     86485.15
# DEPT STREETS AND SANITATION                                  72742.38
# FAMILY AND SUPPORT SERVICES                                  98501.38
# FIRE DEPARTMENT                                              98104.67
# GENERAL SERVICES                                                 0.00
# HOUSING AND ECONOMIC DEVELOPMT                               97223.55
# INDEPENDENT POLICE REVIEW AUTHORITY                          92139.45
# INSPECTOR GENERAL                                            80289.16
# LICENSE APPEAL COMMISSION                                    76932.00
# MAYORS OFFICE-DISABILITIES                                   99625.48
# OFFICE OF BUDGET & MANAGEMENT                               102391.36
# OFFICE OF COMPLIANCE                                             0.00
# OFFICE OF EMERGENCY MANAGEMENT & COMMUNICATIONS              45087.51
# OFFICE OF THE MAYOR                                          95910.05
# POLICE BOARD                                                 86136.00

# %%
# empty list to append salary changes
salary_changes = []

# list of departments for the dataframe
departments = dep_salaries.index

# Calculate department salary changes between 2011 and 2017
for x in range(0, len(dep_budgets)):
    diff = dep_salaries.iloc[x, 6] - dep_salaries.iloc[x, 0]
    salary_changes.append(diff)
    
# create a dataframe for the salary changes
diff_salaries = pd.DataFrame({"Departments": departments,
                            "Salary Changes": salary_changes})

# %%
# save a sorted version of the dataframe
diff_salaries_sorted = diff_salaries[["Departments", "Salary Changes"]]
diff_salaries_sorted = diff_salaries_sorted.sort_values("Salary Changes", ascending=False)

# reset the index and print the dataframe
diff_salaries_sorted = diff_salaries_sorted.set_index("Departments")

# write the dataframe to a csv
diff_salaries_sorted.to_csv("diff_salaries_sorted.csv", index=True)

diff_salaries_sorted
# Out:
#                                                  Salary Changes
# Departments
# FAMILY AND SUPPORT SERVICES                            46923.99
# DEPARTMENT OF PUBLIC HEALTH                            35393.27
# MAYORS OFFICE-DISABILITIES                             25666.51
# COMMISSION ON HUMAN RELATIONS                          25279.17
# DEPT OF BUILDINGS                                      19204.88
# FIRE DEPARTMENT                                        17893.47
# HOUSING AND ECONOMIC DEVELOPMT                         16581.42
# INDEPENDENT POLICE REVIEW AUTHORITY                    14185.76
# BOARD OF ETHICS                                        13882.21
# LICENSE APPEAL COMMISSION                              13656.00
# OFFICE OF BUDGET & MANAGEMENT                          12029.01
# OFFICE OF THE MAYOR                                    11797.05
# CHICAGO PUBLIC LIBRARY                                 11681.36
# DEPARTMENT OF POLICE                                   11589.05
# DEPARTMENT OF INNOVATION & TECHNOLOGY                  10191.90
# CITY CLERK                                              9009.32
# DEPT OF ADMINISTRATIVE HEARING                          8747.20
# POLICE BOARD                                            8448.00
# DEPARTMENT OF FLEET MANAGEMENT                          7993.28
# CHICAGO DEPT OF TRANSPORTATION                          7903.66
# BUSINESS AFFAIRS AND CONSUMER PROTECTION                7616.30
# DEPARTMENT OF AVIATION                                  7454.04
# DEPT OF WATER MANAGEMENT                                7449.73
# CULTURAL AFFAIRS SPECIAL EVENT                          6003.69
# DEPT STREETS AND SANITATION                             5798.82
# CITY TREASURER                                          5543.65
# DEPARTMENT OF HUMAN RESOURCES                           5346.36
# COMM ANIMAL CARE AND CONTROL                            3482.66
# INSPECTOR GENERAL                                       2067.99
# DEPARTMENT OF LAW                                       2012.03
# CITY COUNCIL                                            1890.24
# DEPARTMENT OF PROCUREMENT SERV                          1830.40
# BOARD OF ELECTION COMMISSIONER                         -1067.46
# DEPARTMENT OF FINANCE                                  -8263.89
# OFFICE OF EMERGENCY MANAGEMENT & COMMUNICATIONS       -19876.93
# DEPARTMENT OF REVENUE                                 -58298.82
# GENERAL SERVICES                                      -70981.50
# DEPARTMENT OF ENVIRONMENT                             -76244.10
# OFFICE OF COMPLIANCE                                  -81114.55

# %% [markdown]
# ## Summarize City Financial Data
#
# - per year

# %%
fin_years = [2011, 2012, 2013, 2014, 2015, 2016]

# empty lists to append data to
tot_budgets = []
labels = []

# create a dataframe showing the yearly total city budgets from 2011 to 2016
for year in fin_years:
    budget_total = dep_budgets[f"{year} Dept Budgets"].sum()
    tot_budgets.append(budget_total)
    labels.append(f"{year}")
    
# create a dataframe to hold the city financial information    
total_budgets = pd.DataFrame({"Year": labels,
                            "City Budget": tot_budgets})

#Add yearly city financial data to the dataframe
total_budgets["Total Assets"] = yearly_financials["Total Assets"]
total_budgets["Total Liabilities"] = yearly_financials["Total Liabilities"]
total_budgets["Interest Debt"] = yearly_financials["Interest Debt"]
total_budgets["Property Tax Revenue"] = yearly_financials["Property Tax Revenue"]
total_budgets["Total Expenses"] = yearly_financials["Total Expenses"]
total_budgets["Total Revenue"] = yearly_financials["Total Revenue"]
total_budgets["Net Position"] = yearly_financials["Net Position"]

#rearrange dataframe
total_budgets = total_budgets[["Year", "City Budget", "Total Assets", "Total Liabilities", "Interest Debt", "Property Tax Revenue", \
              "Total Expenses", "Total Revenue", "Net Position"]]

# write the dataframe to a csv
total_budgets.to_csv("total_budgets.csv", index=False)

total_budgets[["Year", "City Budget", "Total Assets", "Total Liabilities", "Interest Debt", "Property Tax Revenue", \
              "Total Expenses", "Total Revenue", "Net Position"]]
# Out:
#    Year  City Budget  Total Assets  Total Liabilities  Interest Debt  \
# 0  2011   2664496474   30477700000        29747300000      474600000
# 1  2012   2567845412   30980900000        31963700000      459900000
# 2  2013   2609932815   30744900000        33395300000      477900000
# 3  2014   2645370284   32694700000        36009500000      580700000
# 4  2015   2783845781   42128100000        62562600000      861300000
# 5  2016   2852220338   41294400000        64703700000      495800000
#
#    Property Tax Revenue  Total Expenses  Total Revenue  Net Position
# 0             934800000      8582400000     7543300000   -2609900000
# 1             893300000      8838600000     7590800000   -4283300000
# 2             906700000      8912500000     7824700000   -5371100000
# 3             926800000      9319300000     8154100000   -6536300000
# 4            1179400000     14364800000     8947100000  -23831400000
# 5            1264500000     13003600000     9405100000  -27429900000
